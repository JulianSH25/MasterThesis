# %%
import pandas as pd

df = pd.read_csv("optimal_results_qaoa.csv")
#print(df)

print(df[df["m"] == 3])
print(df[df["m"] == 4]["result"])

check = df.loc[df["m"] == 4, "result"].item()
print(check)
# Out:
#    m  result
# 2  3   2.366
# 3    2.928
# Name: result, dtype: float64
# 2.928
